# %% [markdown]
# # The Power of Data
# ## Reading, cleaning and visualizing data
# ### Test (15 marks)
#
#
# # Instructions
#
# Please read the following instructions carefully before starting.
#
# - You are allowed to consult **any code or notes stored on your computer** (for example previous notebooks, exercises, or documentation you have written).
#
# - **AI-assisted coding tools must be disabled** during this task. This includes tools such as **GitHub Copilot, ChatGPT, or any other AI code assistants**.
#
# - You **do not need to answer the questions in order**. You may complete them in any sequence you prefer.
#
# - If you need to search for programming help, you may only consult **StackOverflow** and **GeeksForGeeks**.
#   To do this, use the following restricted search link and type your query after it:
#
#   https://www.google.com/search?q=site:stackoverflow.com+OR+site:geeksforgeeks.org+OR+w3schools.com
#
#   Example searches:
#   - `site:stackoverflow.com OR site:geeksforgeeks.org pandas how to delete column`
#   - `site:stackoverflow.com OR site:geeksforgeeks.org pandas finding mean of column`
#
#
# - Before submitting your work, you must click **`Run All`** to ensure that all cells execute correctly and that your outputs appear in the notebook.
#
# - Once you have verified that everything runs correctly:
#   1. **Save the notebook**
#   2. **Submit the `.ipynb` file on Teams**

# %% [markdown]
# ### Question 1
# Load the CSV dataset into a variable called **`df`**.
#
# <span style="color:red">(1 mark)</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### Question 2
# Display the **first 7 rows** of the dataset.
#
# <span style="color:red">(1 mark)</span>

# %%
df.head(7)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Question 3
# Write code to determine **how many missing (empty) values each column contains**.
#
# <span style="color:red">(1 mark)</span>

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### Question 4
# Determine the **percentage of missing values** in the **`country`** column.
#
# <span style="color:red">(1 mark)</span>

# %%
print(f'{df.isnull().sum()["country"]/len(df["country"])*100}%')
# Out:
# 9.435676166685592%

# %% [markdown]
# ### Question 5
# Replace the missing values in the **`country`** column using the **mode (most common value)**.
#
# <span style="color:red">(2 marks)</span>

# %%
df["country"] = df["country"].fillna(df["country"].mode()[0])
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country            0
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### Question 6
# Determine, using code, **how many unique values** appear in the **`type`** column.
#
# <span style="color:red">(1 mark)</span>

# %%
print(f"Number of Unique values: {df["type"].nunique()}")
print(f"{df["type"].unique()[0]}, {df["type"].unique()[1]}")
#Therefore, 2 Unique values, Movie and TV Show
# Out:
# Number of Unique values: 2
# Movie, TV Show

# %% [markdown]
# ### Question 7
# Determine the **minimum and maximum values** in the **`release_year`** column.
#
# <span style="color:red">(1 mark)</span>

# %%
years = df["release_year"].unique()
years.sort()
print(years)
#Minimum is 1925, Maximum is 2021
# Out:
# [1925 1942 1943 1944 1945 1946 1947 1954 1955 1956 1958 1959 1960 1961
#  1962 1963 1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975
#  1976 1977 1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989
#  1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021]

# %% [markdown]
# ### Question 8
# Remove the column **`show_id`** from the dataset.
#
# <span style="color:red">(1 mark)</span>

# %%
df.drop(['show_id'], axis=1, inplace=True)
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                                NaN  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ### Question 9
# Determine **which director appears most frequently** in the dataset.
#
# <span style="color:red">(1 mark)</span>

# %%
df["director"].value_counts()
#Rajiv Chilaka
# Out:
# director
# Rajiv Chilaka              19
# Raúl Campos, Jan Suter     18
# Suhas Kadav                16
# Marcus Raboy               16
# Jay Karas                  14
#                            ..
# Mu Chu                      1
# Chandra Prakash Dwivedi     1
# Majid Al Ansari             1
# Peter Hewitt                1
# Mozez Singh                 1
# Name: count, Length: 4528, dtype: int64

# %% [markdown]
# ### Question 10
# Create a **bar chart** showing how many times each country appears in the dataset.
# The chart title must be:
#
# **"Country popularity on Netflix"**
#
# <span style="color:red">(2 marks)</span>

# %%
# Plot number of passengers that survived
fig1, ax1 = plt.subplots(figsize=(8, 5))
country_counts = df['country'].value_counts(sort=True).head(10)
country_counts.plot(kind='bar', color=['#E50914', "#F32B2B", "#F75959", "#F77777", "#F9A1A1", "#FACACA", "#F8D5D5", "#F7DFDF", "#FAE9E9", "#F7E8E8"], ax=ax1)
ax1.set_title('Country popularity on Netflix(Top 10)', fontsize=16, color="#E50914")
ax1.set_xlabel('Countries', fontsize=12, color="#E50914")
ax1.set_ylabel('Count', fontsize=12, color="#E50914")
ax1.set_facecolor("white")

# %% [markdown]
# ### Question 11
# Convert the **`type`** column into a numerical column.
#
# <span style="color:red">(2 marks)</span>

# %%
#Let TV Show be 0 and Movie be 1
df["type"] = df["type"].replace({"TV Show": 0, "Movie":1})

# %% [markdown]
# ### Question 12
# Save the cleaned dataset to a new file called:
#
# **`netflix_titles_cleaned.csv`**
#
# <span style="color:red">(1 mark)</span>

# %%
df.to_csv('netflix_titles_cleaned.csv', index=False)

# %%
# Extension
df["month"] = df["date_added"]
df["month"] = df["month"].str.replace("January", "1", regex=False)
df["month"] = df["month"].str.replace("Febuary", "2", regex=False)
df["month"] = df["month"].str.replace("March", "3", regex=False)
df["month"] = df["month"].str.replace("April", "4", regex=False)
df["month"] = df["month"].str.replace("May", "5", regex=False)
df["month"] = df["month"].str.replace("June", "6", regex=False)
df["month"] = df["month"].str.replace("July", "7", regex=False)
df["month"] = df["month"].str.replace("August", "8", regex=False)
df["month"] = df["month"].str.replace("September", "9", regex=False)
df["month"] = df["month"].str.replace("October", "10", regex=False)
df["month"] = df["month"].str.replace("November", "11", regex=False)
df["month"] = df["month"].str.replace("December", "12", regex=False)

df["month"] = df["month"].str.replace(",", "")

for i in range(5):
    for i in range(32):
        df["month"] = df["month"].str.replace(f" {i}", " ", regex=False)




df.head(10)
# Out:
#   type                             title                       director  \
# 0    1              Dick Johnson Is Dead                Kirsten Johnson
# 1    0                     Blood & Water                            NaN
# 2    0                         Ganglands                Julien Leclercq
# 3    0             Jailbirds New Orleans                            NaN
# 4    0                      Kota Factory                            NaN
# 5    0                     Midnight Mass                  Mike Flanagan
# 6    1  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    1                           Sankofa                   Haile Gerima
# 8    0     The Great British Baking Show                Andy Devonshire
# 9    1                      The Starling                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...
